# %%
import os
import re
import random
import shutil
from typing import Tuple, List
from PIL import Image

import albumentations as A
import cv2
import imageio
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

from yolo_utils import *

# %matplotlib inline

IMAGES_PATH = "/kaggle/input/11-xhec/images"
LABELS_PATH = "/kaggle/working/chronsite_images/labels/train"

FORMATTED_IMAGES_PATH = "/kaggle/working/chronsite_images_formatted/images/train"
FORMATTED_LABELS_PATH = "/kaggle/working/chronsite_images_formatted/labels/train"

VAL_IMAGES_PATH = "/kaggle/working/chronsite_images_formatted/images/val"

TEST_IMAGES_PATH = "/kaggle/input/11-xhec/Detection_Test_Set_Img/Detection_Test_Set_Img"
FORMATTED_TEST_IMAGES_PATH = "/kaggle/working/Detection_Test_Set_Img"

CSV_LABELS_PATH = "/kaggle/input/11-xhec/bboxes_yolo.csv"
CONFIG_FILE_PATH = "test_chronsite.yaml"

IMAGE_DIMENSION = 1920
N_IMAGES = 0     # set to 0 for all images available
BATCH_SIZE = 2    # too big will result in memory error
EPOCHS = 30
YOLO_SIZE = "l"   # "s" for small, "m" for medium, "l" for large, "x" for extra-large
VAL_SET_SIZE = 0.1
CONF_THRES_PRED = 0.4
N_AUGMENTATIONS = 0   # Number of augmentation of test images

# %%
clone_yolo_repo()

make_arborescence(LABELS_PATH, FORMATTED_IMAGES_PATH, FORMATTED_LABELS_PATH, FORMATTED_TEST_IMAGES_PATH)

write_labels_to_files(CSV_LABELS_PATH)

format_images_and_labels(N_IMAGES, IMAGE_DIMENSION, IMAGES_PATH, 
                         FORMATTED_LABELS_PATH, FORMATTED_IMAGES_PATH)

create_val_set(VAL_SET_SIZE, FORMATTED_IMAGES_PATH, FORMATTED_LABELS_PATH)

augment_train_set(FORMATTED_IMAGES_PATH, FORMATTED_LABELS_PATH, N_AUGMENTATIONS)

# !mv yolov5/* ./

# !pip install -qr requirements.txt

write_yolo_train_config(CONFIG_FILE_PATH, FORMATTED_IMAGES_PATH)

# !python train.py --img {IMAGE_DIMENSION} --batch {BATCH_SIZE} --epochs {EPOCHS} --data /kaggle/working/{CONFIG_FILE_PATH} --cfg /kaggle/working/models/yolov5{YOLO_SIZE}.yaml --name yolov5{YOLO_SIZE}_fold0 --weights yolov5{YOLO_SIZE}.pt
# Out:
# Yolo repo cloned
#
# Created folders organization
#
# Labels written from csv to .txt files
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 1581 images and labels written to disk
# 0 images escaped because of Albumentations' bug
#
# Created validation folders
#
# Validation set created with 10% of initial images!
# 0 images not augmented because of bug
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# hypertools 0.6.2 requires scikit-learn<0.22,>=0.19.1, but you'll have scikit-learn 0.23.2 which is incompatible.
# Config written:
#
#     # train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
#     train: /kaggle/working/chronsite_images_formatted/images/train
#     val: /kaggle/working/chronsite_images_formatted/images/val
#
#     # number of classes
#     nc: 2
#
#     # class names
#     names: ['People', 'Mixer_truck']
#
#
# 2020-10-06 16:33:17.815970: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Downloading https://github.com/ultralytics/yolov5/releases/download/v3.0/yolov5l.pt to yolov5l.pt...
# 100%|██████████████████████████████████████| 91.6M/91.6M [00:02<00:00, 38.3MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
# Scanning images: 100%|████████████████████| 1386/1386 [00:00<00:00, 4249.43it/s]
# Scanning labels /kaggle/working/chronsite_images_formatted/labels/train.cache (1330 found, 0 missing, 56 empty, 2 duplicate, for 1386 images): 1386it [00:00, 12585.06it/s]
# Scanning images: 100%|██████████████████████| 153/153 [00:00<00:00, 3452.12it/s]
# Scanning labels /kaggle/working/chronsite_images_formatted/labels/val.cache (152 found, 0 missing, 1 empty, 0 duplicate, for 153 images): 153it [00:00, 7517.73it/s]
#
# Analyzing anchors... anchors/target = 4.55, Best Possible Recall (BPR) = 1.0000
#       0/29     10.7G   0.09629   0.01502   0.01678    0.1281        13      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03           0           0      0.0539      0.0111
#       1/29     10.6G    0.0735   0.01035   0.00495    0.0888        15      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03           1     0.00938       0.191      0.0796
#       2/29     10.6G    0.0708  0.008927  0.003897   0.08362         7      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03         0.5     0.00893       0.292      0.0755
#       3/29     10.6G   0.06329  0.008101  0.002772   0.07417        12      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.702       0.148        0.28      0.0972
#       4/29     10.6G   0.05823   0.00751  0.001791   0.06753        52      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.673       0.333       0.424       0.136
#       5/29     10.6G   0.05596  0.007194  0.001414   0.06457        21      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.548        0.43       0.463       0.212
#       6/29     10.6G   0.05368  0.006879  0.001472   0.06203        46      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03         0.5       0.511       0.485       0.197
#       7/29     10.6G   0.05259  0.006611   0.00125   0.06045         9      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.482       0.595       0.541       0.231
#       8/29     10.6G   0.05138  0.006301  0.001002   0.05868         7      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03        0.52       0.644       0.601       0.291
#       9/29     10.6G   0.05035  0.006226 0.0009072   0.05749         5      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.397       0.686       0.611       0.269
#      10/29     10.6G   0.04844  0.006272 0.0006894   0.05541        32      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.508       0.692       0.625       0.295
#      11/29     10.6G   0.04831  0.006328 0.0006825   0.05532        13      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.546       0.699       0.672       0.351
#      12/29     10.6G   0.04742  0.006098 0.0006878   0.05421        10      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.554        0.68       0.654       0.322
#      13/29     10.6G   0.04664  0.005971 0.0006921    0.0533         6      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03        0.38        0.77        0.64       0.323
#      14/29     10.6G   0.04568  0.005619 0.0005123   0.05181         8      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.544        0.75        0.71        0.37
#      15/29     10.6G   0.04506  0.005768 0.0004745   0.05131        28      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.567       0.763       0.713       0.395
#      16/29     10.6G   0.04415    0.0056   0.00053   0.05028        11      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.542       0.779       0.712       0.398
#      17/29     10.6G   0.04369    0.0056 0.0003461   0.04964        20      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.562        0.78       0.717       0.402
#      18/29     10.6G   0.04382  0.005571 0.0004192   0.04981        21      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.515       0.769       0.717       0.403
#      19/29     10.6G   0.04234  0.005281 0.0003308   0.04795        33      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.558       0.775       0.729       0.398
#      20/29     10.6G   0.04213  0.005365  0.000326   0.04782         8      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.524        0.78       0.731       0.378
#      21/29     10.6G   0.04228  0.005467 0.0004215   0.04817        12      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.482       0.801       0.748       0.426
#      22/29     10.6G   0.04185  0.005421 0.0003112   0.04758        19      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.554       0.809       0.754         0.4
#      23/29     10.6G   0.04003   0.00535 0.0003015   0.04568         8      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.499       0.817       0.744       0.421
#      24/29     10.6G   0.04109  0.005202 0.0003007   0.04659        42      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03        0.53       0.822       0.757        0.43
#      25/29     10.6G   0.04008  0.005139 0.0002046   0.04542        15      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03         0.6       0.814       0.756       0.429
#      26/29     10.6G   0.03975  0.005198 0.0002027   0.04515        33      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.545       0.818       0.763       0.419
#      27/29     10.6G   0.03952  0.005036 0.0002135   0.04477         6      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.493       0.824       0.757       0.441
#      28/29     10.6G   0.03951  0.005261 0.0001958   0.04497        51      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.525       0.822        0.76       0.439
#      29/29     10.6G    0.0386  0.005044 0.0001965   0.04385        10      1920
#                Class      Images     Targets           P           R      mAP@.5
#                  all         153    1.17e+03       0.509       0.838       0.768       0.449
# Optimizer stripped from runs/exp0_yolov5l_fold0/weights/last.pt, 95.8MB
# Optimizer stripped from runs/exp0_yolov5l_fold0/weights/best.pt, 95.8MB

# %%
weights_folder = [p for p in os.listdir("/kaggle/working/runs") if re.match(r"exp\d", p)][-1]
weights_path = f"./runs/{weights_folder}/weights/best.pt"

print(weights_path)
# Out:
# ./runs/exp0_yolov5l_fold0/weights/best.pt

# %%
format_test_images(TEST_IMAGES_PATH, FORMATTED_TEST_IMAGES_PATH, IMAGE_DIMENSION)

#/kaggle/working/chronsite_images_formatted/images/val

! python detect.py --img-size {IMAGE_DIMENSION} --save-txt --source /kaggle/working/Detection_Test_Set_Img --weights ./runs/exp0_yolov5l_fold0/weights/best.pt --conf 0.01
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.01, device='', img_size=1920, iou_thres=0.5, output='inference/output', save_txt=True, source='/kaggle/working/Detection_Test_Set_Img', update=False, view_img=False, weights=['./runs/exp0_yolov5l_fold0/weights/best.pt'])
# Fusing layers...
# image 1/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-13-30-11.jpg: 1920x1920 1 Peoples, Done. (0.154s)
# image 2/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-13-42-19.jpg: 1920x1920 7 Peoples, Done. (0.153s)
# image 3/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-13-54-13.jpg: 1920x1920 8 Peoples, Done. (0.153s)
# image 4/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-14-06-24.jpg: 1920x1920 10 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 5/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-14-18-46.jpg: 1920x1920 11 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 6/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-14-30-46.jpg: 1920x1920 15 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 7/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-14-42-56.jpg: 1920x1920 10 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 8/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-14-55-14.jpg: 1920x1920 8 Peoples, Done. (0.153s)
# image 9/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-15-07-15.jpg: 1920x1920 11 Peoples, 2 Mixer_trucks, Done. (0.152s)
# image 10/100 /kaggle/working/Detection_Test_Set_Img/2019-10-17-15-19-05.jpg: 1920x1920 9 Peoples, Done. (0.153s)
# image 11/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-23-38.jpg: 1920x1920 20 Peoples, Done. (0.153s)
# image 12/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-33-43.jpg: 1920x1920 19 Peoples, Done. (0.153s)
# image 13/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-36-02.jpg: 1920x1920 22 Peoples, Done. (0.153s)
# image 14/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-46-06.jpg: 1920x1920 35 Peoples, Done. (0.153s)
# image 15/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-49-12.jpg: 1920x1920 20 Peoples, Done. (0.153s)
# image 16/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-51-32.jpg: 1920x1920 30 Peoples, Done. (0.153s)
# image 17/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-53-05.jpg: 1920x1920 28 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 18/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-55-24.jpg: 1920x1920 24 Peoples, Done. (0.154s)
# image 19/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-11-56-11.jpg: 1920x1920 31 Peoples, Done. (0.152s)
# image 20/100 /kaggle/working/Detection_Test_Set_Img/2020-07-15-12-01-36.jpg: 1920x1920 39 Peoples, Done. (0.153s)
# image 21/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-09-14-46.jpg: 1920x1920 14 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 22/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-09-54-07.jpg: 1920x1920 11 Peoples, Done. (0.153s)
# image 23/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-11-46-06.jpg: 1920x1920 7 Peoples, Done. (0.153s)
# image 24/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-11-46-52.jpg: 1920x1920 10 Peoples, Done. (0.153s)
# image 25/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-11-47-37.jpg: 1920x1920 7 Peoples, Done. (0.152s)
# image 26/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-11-49-08.jpg: 1920x1920 12 Peoples, Done. (0.153s)
# image 27/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-13-29-02.jpg: 1920x1920 23 Peoples, Done. (0.153s)
# image 28/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-14-06-07.jpg: 1920x1920 7 Peoples, Done. (0.154s)
# image 29/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-14-07-38.jpg: 1920x1920 13 Peoples, 3 Mixer_trucks, Done. (0.154s)
# image 30/100 /kaggle/working/Detection_Test_Set_Img/2020-07-27-14-25-48.jpg: 1920x1920 19 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 31/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-18-30-05.jpg: 1920x1920 6 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 32/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-18-30-50.jpg: 1920x1920 11 Peoples, Done. (0.153s)
# image 33/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-18-33-52.jpg: 1920x1920 7 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 34/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-18-39-10.jpg: 1920x1920 8 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 35/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-18-50-31.jpg: 1920x1920 8 Peoples, Done. (0.153s)
# image 36/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-19-04-08.jpg: 1920x1920 7 Peoples, Done. (0.153s)
# image 37/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-19-13-58.jpg: 1920x1920 15 Peoples, Done. (0.153s)
# image 38/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-19-16-59.jpg: 1920x1920 9 Peoples, Done. (0.153s)
# image 39/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-19-44-13.jpg: 1920x1920 7 Peoples, Done. (0.153s)
# image 40/100 /kaggle/working/Detection_Test_Set_Img/2020-08-13-20-43-15.jpg: 1920x1920 6 Peoples, Done. (0.153s)
# image 41/100 /kaggle/working/Detection_Test_Set_Img/frame0449.jpg: 1920x1920 71 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 42/100 /kaggle/working/Detection_Test_Set_Img/frame0454.jpg: 1920x1920 106 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 43/100 /kaggle/working/Detection_Test_Set_Img/frame0459.jpg: 1920x1920 41 Peoples, Done. (0.153s)
# image 44/100 /kaggle/working/Detection_Test_Set_Img/frame0464.jpg: 1920x1920 90 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 45/100 /kaggle/working/Detection_Test_Set_Img/frame0469.jpg: 1920x1920 91 Peoples, Done. (0.153s)
# image 46/100 /kaggle/working/Detection_Test_Set_Img/frame0474.jpg: 1920x1920 53 Peoples, Done. (0.153s)
# image 47/100 /kaggle/working/Detection_Test_Set_Img/frame0479.jpg: 1920x1920 89 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 48/100 /kaggle/working/Detection_Test_Set_Img/frame0484.jpg: 1920x1920 95 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 49/100 /kaggle/working/Detection_Test_Set_Img/frame0489.jpg: 1920x1920 82 Peoples, Done. (0.153s)
# image 50/100 /kaggle/working/Detection_Test_Set_Img/frame0494.jpg: 1920x1920 50 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 51/100 /kaggle/working/Detection_Test_Set_Img/frame0499.jpg: 1920x1920 39 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 52/100 /kaggle/working/Detection_Test_Set_Img/frame0504.jpg: 1920x1920 74 Peoples, Done. (0.154s)
# image 53/100 /kaggle/working/Detection_Test_Set_Img/frame0509.jpg: 1920x1920 76 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 54/100 /kaggle/working/Detection_Test_Set_Img/frame0514.jpg: 1920x1920 86 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 55/100 /kaggle/working/Detection_Test_Set_Img/frame0519.jpg: 1920x1920 56 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 56/100 /kaggle/working/Detection_Test_Set_Img/frame1578.jpg: 1920x1920 58 Peoples, 1 Mixer_trucks, Done. (0.154s)
# image 57/100 /kaggle/working/Detection_Test_Set_Img/frame1581.jpg: 1920x1920 54 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 58/100 /kaggle/working/Detection_Test_Set_Img/frame1585.jpg: 1920x1920 61 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 59/100 /kaggle/working/Detection_Test_Set_Img/frame1589.jpg: 1920x1920 50 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 60/100 /kaggle/working/Detection_Test_Set_Img/frame1592.jpg: 1920x1920 66 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 61/100 /kaggle/working/Detection_Test_Set_Img/frame1596.jpg: 1920x1920 80 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 62/100 /kaggle/working/Detection_Test_Set_Img/frame1602.jpg: 1920x1920 86 Peoples, 2 Mixer_trucks, Done. (0.154s)
# image 63/100 /kaggle/working/Detection_Test_Set_Img/frame1606.jpg: 1920x1920 53 Peoples, 2 Mixer_trucks, Done. (0.154s)
# image 64/100 /kaggle/working/Detection_Test_Set_Img/frame1613.jpg: 1920x1920 53 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 65/100 /kaggle/working/Detection_Test_Set_Img/frame1617.jpg: 1920x1920 56 Peoples, Done. (0.153s)
# image 66/100 /kaggle/working/Detection_Test_Set_Img/frame1620.jpg: 1920x1920 51 Peoples, Done. (0.153s)
# image 67/100 /kaggle/working/Detection_Test_Set_Img/frame1624.jpg: 1920x1920 45 Peoples, Done. (0.153s)
# image 68/100 /kaggle/working/Detection_Test_Set_Img/frame1628.jpg: 1920x1920 71 Peoples, Done. (0.153s)
# image 69/100 /kaggle/working/Detection_Test_Set_Img/frame1631.jpg: 1920x1920 55 Peoples, Done. (0.153s)
# image 70/100 /kaggle/working/Detection_Test_Set_Img/frame510.jpg: 1920x1920 33 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 71/100 /kaggle/working/Detection_Test_Set_Img/frame512.jpg: 1920x1920 14 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 72/100 /kaggle/working/Detection_Test_Set_Img/frame514.jpg: 1920x1920 22 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 73/100 /kaggle/working/Detection_Test_Set_Img/frame515.jpg: 1920x1920 20 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 74/100 /kaggle/working/Detection_Test_Set_Img/frame516.jpg: 1920x1920 21 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 75/100 /kaggle/working/Detection_Test_Set_Img/frame517.jpg: 1920x1920 23 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 76/100 /kaggle/working/Detection_Test_Set_Img/frame518.jpg: 1920x1920 22 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 77/100 /kaggle/working/Detection_Test_Set_Img/frame519.jpg: 1920x1920 12 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 78/100 /kaggle/working/Detection_Test_Set_Img/frame520.jpg: 1920x1920 18 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 79/100 /kaggle/working/Detection_Test_Set_Img/frame521.jpg: 1920x1920 27 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 80/100 /kaggle/working/Detection_Test_Set_Img/frame522.jpg: 1920x1920 23 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 81/100 /kaggle/working/Detection_Test_Set_Img/frame523.jpg: 1920x1920 28 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 82/100 /kaggle/working/Detection_Test_Set_Img/frame524.jpg: 1920x1920 21 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 83/100 /kaggle/working/Detection_Test_Set_Img/frame525.jpg: 1920x1920 33 Peoples, Done. (0.153s)
# image 84/100 /kaggle/working/Detection_Test_Set_Img/frame526.jpg: 1920x1920 35 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 85/100 /kaggle/working/Detection_Test_Set_Img/frame527.jpg: 1920x1920 14 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 86/100 /kaggle/working/Detection_Test_Set_Img/frame528.jpg: 1920x1920 21 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 87/100 /kaggle/working/Detection_Test_Set_Img/frame529.jpg: 1920x1920 35 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 88/100 /kaggle/working/Detection_Test_Set_Img/frame944.jpg: 1920x1920 83 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 89/100 /kaggle/working/Detection_Test_Set_Img/frame946.jpg: 1920x1920 48 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 90/100 /kaggle/working/Detection_Test_Set_Img/frame948.jpg: 1920x1920 59 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 91/100 /kaggle/working/Detection_Test_Set_Img/frame951.jpg: 1920x1920 68 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 92/100 /kaggle/working/Detection_Test_Set_Img/frame953.jpg: 1920x1920 58 Peoples, Done. (0.153s)
# image 93/100 /kaggle/working/Detection_Test_Set_Img/frame955.jpg: 1920x1920 82 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 94/100 /kaggle/working/Detection_Test_Set_Img/frame957.jpg: 1920x1920 57 Peoples, 1 Mixer_trucks, Done. (0.153s)
# image 95/100 /kaggle/working/Detection_Test_Set_Img/frame959.jpg: 1920x1920 62 Peoples, 3 Mixer_trucks, Done. (0.153s)
# image 96/100 /kaggle/working/Detection_Test_Set_Img/frame960.jpg: 1920x1920 56 Peoples, 4 Mixer_trucks, Done. (0.153s)
# image 97/100 /kaggle/working/Detection_Test_Set_Img/frame962.jpg: 1920x1920 59 Peoples, 2 Mixer_trucks, Done. (0.153s)
# image 98/100 /kaggle/working/Detection_Test_Set_Img/frame964.jpg: 1920x1920 89 Peoples, Done. (0.153s)
# image 99/100 /kaggle/working/Detection_Test_Set_Img/frame966.jpg: 1920x1920 81 Peoples, Done. (0.154s)
# image 100/100 /kaggle/working/Detection_Test_Set_Img/frame968.jpg: 1920x1920 95 Peoples, Done. (0.153s)
# Results saved to inference/output
# Done. (30.617s)

# %%
#os.listdir("/kaggle/working/inference/output")

# %%
def gather_predictions(txt_output_path: str) -> pd.DataFrame:
    text_files_paths = [p for p in os.listdir(txt_output_path) if ".txt" in p]
    
    total_objects_detected = dict()
    for text_file_path in text_files_paths:
        with open(os.path.join(txt_output_path, text_file_path)) as f:
            for i, line in enumerate(f.read().split("\n")):
                if line:
                    total_objects_detected[f"{text_file_path}_{i}"] = line.split()
                    
    df_objects_detected = pd.DataFrame(total_objects_detected).T
    
    col_types = {"category": int, "x_center": float, "y_center": float, "width": float, "height": float}
    df_objects_detected.columns = list(col_types.keys())
    df_objects_detected = df_objects_detected.astype(col_types)

    return df_objects_detected

# %%
df_objects_pred = gather_predictions("/kaggle/working/inference/output")

df_objects_pred.to_csv("predictions_yolonet.csv")

# %%
# !rm -rf /kaggle/working/inference/output
# !rm -rf /kaggle/working/utils
# !rm -rf /kaggle/working/yolov5
# !rm -rf /kaggle/working/chronsite_images
# !rm -rf /kaggle/working/Detection_Test_Set_Img

# %%
from PIL import Image, ImageFont, ImageDraw, ImageEnhance

def from_yolo_to_cor(box, shape):
    img_h, img_w, _ = shape
    x1, y1 = int((box[0] + box[2]/2)*img_w), int((box[1] + box[3]/2)*img_h)
    x2, y2 = int((box[0] - box[2]/2)*img_w), int((box[1] - box[3]/2)*img_h)
    return x1, y1, x2, y2

def draw_boxes(img, boxes, categories, mapping):
    draw = ImageDraw.Draw(img)
    
    for box, categ in zip(boxes, categories):
        x1, y1, x2, y2 = from_yolo_to_cor(box, np.asarray(img).shape)
        draw.rectangle((x1, y1, x2, y2), outline="green")
        draw.text((x1, y1), f"GT: {mapping[categ]}")

    display(img)

# %%
VAL_IMAGES_TO_SHOW = 5
MAPPING = {0: "People", 1: "Mixter Truck"}

for _ in range(VAL_IMAGES_TO_SHOW):

    random_infered_image = random.choice([p for p in os.listdir("inference/output") if ".jpg" in p])
    #print(random_infered_image)

    im = Image.open(f"inference/output/{random_infered_image}").resize((700, 700))
"""
    with open("/kaggle/working/chronsite_images_formatted/labels/val/" + random_infered_image.split(".")[0] + ".txt") as f:
        annot = f.read()
        bboxes = [list(map(float, s.split()[1:])) for s in f.read().split("\n") if s]
        categories = [list(map(float, s.split()[0]))[0] for s in annot.split("\n") if s]

    draw_boxes(im, bboxes, categories, MAPPING)"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-fedc3eac9b12> in <module>
#       4 for _ in range(VAL_IMAGES_TO_SHOW):
#       5
# ----> 6     random_infered_image = random.choice([p for p in os.listdir("inference/output") if ".jpg" in p])
#       7     #print(random_infered_image)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'inference/output'
